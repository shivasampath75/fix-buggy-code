# %% [markdown]
# <a href="https://colab.research.google.com/github/Joydeep-06/fix-buggy-code/blob/main/Copy_of_Buggy_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the **Bugs** in the code

# %%
#Fix the error

def calculate_average(numbers):

  total = sum(numbers)
  avg = total / len(numbers)
  return avrg


# Test case
numbers = [10, 20, 30, 40, 50]
print("Average:", calculate_average(numbers))
